# %% [markdown]
# ### 画像の確認

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import math
import pydicom

# %%
img_file2 = "../dataset/LUNG1-086/0.000000-NA-69646/1-084.dcm"
file = pydicom.dcmread(img_file2)
file_data2 = file.pixel_array

file_data2.shape
# Out:
# (512, 512)

# %%
plt.imshow(file_data2)

# %%
plt.imshow(aa[80,:,:], origin='lower')

# %%
from mayavi import mlab
import os
os.environ['ETS_TOOLKIT']='qt4'
mlab.figure()
mlab.contour3d(aa, contours=5, opacity=0.5)
mlab.show()

# %%
img_file = '../dataset/LUNG1-086/LUNG1-086_thor_cav_primary_reviewer.nii.gz'
img = nib.load(img_file)

# %%
img_data = img.get_fdata()

img_data.shape
# Out:
# (512, 512, 176)

# %%
# 一次元に変換
array_1d = aa.flatten()
print(aa.max())
# ヒストグラムの作成
plt.hist(array_1d, bins=100, edgecolor='black')
plt.title('Histogram of 3D Array Elements')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
# Out:
# 1
